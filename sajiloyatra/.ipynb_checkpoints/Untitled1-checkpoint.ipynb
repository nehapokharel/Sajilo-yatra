# %%
import pandas as pd
df = pd.read_csv("FoodReview.csv")

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['food'],df['reviewer'])

# %%
X=df[['food','review']]
y=df['reviewer']

# %%
X
# Out:
#      food                                             review
# 0       2                                Yummy just loved it
# 1       2                                Yummy just loved it
# 2       2                                Yummy just loved it
# 3       2                                Yummy just loved it
# 4       2                                Yummy just loved it
# 5       2                                Yummy just loved it
# 6       2                      nice snack with awesome taste
# 7       2             nice snack with awesome taste must try
# 8       2                      nice snack with awesome taste
# 9       2                                very horrible taste
# 10      2                                           Not good
# 11      2                      nice snack with awesome taste
# 12      2                      nice snack with awesome taste
# 13      2                      nice snack with awesome taste
# 14      2                      nice snack with awesome taste
# 15      2                      nice snack with awesome taste
# 16      2                      nice snack with awesome taste
# 17      2                      nice snack with awesome taste
# 18      2                      nice snack with awesome taste
# 19      2  nice snack with awesome taste never miss while...
# 20      2             nice snack with awesome taste must try
# 21      2                      nice snack with awesome taste
# 22      2                      nice snack with awesome taste
# 23      2                      nice snack with awesome taste
# 24      2                                  nice sweet snacks
# 25      2                                   awesome must try
# 26      2                                   awesome must try
# 27      2                                   awesome must try
# 28      2                                   awesome must try
# 29      2                                   awesome must try
# ..    ...                                                ...
# 125     1                    sweet and tasty drink. Must try
# 126     1                    sweet and tasty drink. Must try
# 127     1                    sweet and tasty drink. Must try
# 128     1                    sweet and tasty drink. Must try
# 129     1                    sweet and tasty drink. Must try
# 130     1                    sweet and tasty drink. Must try
# 131     1                    sweet and tasty drink. Must try
# 132     1  good drink favorable for both hot and cold season
# 133     1  good drink favorable for both hot and cold season
# 134     1  good drink favorable for both hot and cold season
# 135     1                                         worst food
# 136     1             good sweet and tasty drink. Must taste
# 137     1             good sweet and tasty drink. Must taste
# 138     1             good sweet and tasty drink. Must taste
# 139     1             good sweet and tasty drink. Must taste
# 140     1                                         good drink
# 141     1                                         good drink
# 142     1                                              tasty
# 143     1                                Delicious food ever
# 144     1                                              sweet
# 145     1                                            love it
# 146     1                                 Didn't like at all
# 147     1                                     terrible drink
# 148     1                                           Not good
# 149     1                           one of my favorite drink
# 150     1                                         Good taste
# 151     1                               Not good as expected
# 152     1                                 WOW! Awesome drink
# 153     1                             nice drink. Loved it!!
# 154     1             Nice flavored drink for your breakfast
#
# [155 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
import tflearn
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0625 06:07:55.148184 140537926887232 deprecation_wrapper.py:119] From /home/neha/Envs/sajiloyatra/lib/python3.6/site-packages/tflearn/helpers/summarizer.py:9: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# W0625 06:07:55.149746 140537926887232 deprecation_wrapper.py:119] From /home/neha/Envs/sajiloyatra/lib/python3.6/site-packages/tflearn/helpers/trainer.py:25: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# W0625 06:07:55.158158 140537926887232 deprecation_wrapper.py:119] From /home/neha/Envs/sajiloyatra/lib/python3.6/site-packages/tflearn/collections.py:13: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# W0625 06:07:55.168042 140537926887232 deprecation_wrapper.py:119] From /home/neha/Envs/sajiloyatra/lib/python3.6/site-packages/tflearn/config.py:123: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# W0625 06:07:55.209598 140537926887232 deprecation_wrapper.py:119] From /home/neha/Envs/sajiloyatra/lib/python3.6/site-packages/tflearn/config.py:129: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# W0625 06:07:55.214795 140537926887232 deprecation_wrapper.py:119] From /home/neha/Envs/sajiloyatra/lib/python3.6/site-packages/tflearn/config.py:131: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.

# %%
from tflearn.data_utils import pad_sequences
from keras.utils.np_utils import to_categorical

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=10)

# %%
import pandas as pd

# %%
y_train = to_categorical(y_train, nb_classes=2)
y_test = to_categorical(y_test, nb_classes=2)

# %%
net = tflearn.input_data([None, 100])
net = tflearn.layers.embedding_ops.embedding(net, input_dim=10000, output_dim=128)
net = tflearn.lstm(net,128,dropout=0.8)
net = tflearn.fully_connected(net,2, activation='softmax')
net = tflearn.regression(net,optimizer='adam',learning_rate=0.0001, loss='categorical_crossentropy')
# Out:
# W0625 06:08:53.589087 140537926887232 deprecation_wrapper.py:119] From /home/neha/Envs/sajiloyatra/lib/python3.6/site-packages/tflearn/layers/core.py:81: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0625 06:08:53.596699 140537926887232 deprecation.py:506] From /home/neha/Envs/sajiloyatra/lib/python3.6/site-packages/tflearn/initializations.py:165: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0625 06:08:53.642064 140537926887232 deprecation.py:323] From /home/neha/Envs/sajiloyatra/lib/python3.6/site-packages/tflearn/layers/recurrent.py:69: static_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell, unroll=True)`, which is equivalent to this API
# W0625 06:08:53.697742 140537926887232 deprecation.py:506] From /home/neha/Envs/sajiloyatra/lib/python3.6/site-packages/tflearn/layers/recurrent.py:681: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0625 06:08:53.733291 140537926887232 deprecation.py:506] From /home/neha/Envs/sajiloyatra/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0625 06:08:58.946923 140537926887232 deprecation_wrapper.py:119] From /home/neha/Envs/sajiloyatra/lib/python3.6/site-packages/tflearn/optimizers.py:238: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.

# %%
model = tflearn.DNN(net,tensorboard_verbose=0)
model.fit(X_train,y_train,validation_set=(X_test,y_test),show_metric=True,batch_size=32)
# Out:
# ---------------------------------
# Run id: EPXUSQ
# Log directory: /tmp/tflearn_logs/
# ---------------------------------
# Training samples: 124
# Validation samples: 31
# --
# Exception in thread Thread-6:
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/neha/Envs/sajiloyatra/lib/python3.6/site-packages/tflearn/data_flow.py", line 187, in fill_feed_dict_queue
#     data = self.retrieve_data(batch_ids)
#   File "/home/neha/Envs/sajiloyatra/lib/python3.6/site-packages/tflearn/data_flow.py", line 222, in retrieve_data
#     utils.slice_array(self.feed_dict[key], batch_ids)
#   File "/home/neha/Envs/sajiloyatra/lib/python3.6/site-packages/tflearn/utils.py", line 204, in slice_array
#     return X[start]
#   File "/home/neha/Envs/sajiloyatra/lib/python3.6/site-packages/pandas/core/frame.py", line 2934, in __getitem__
#     raise_missing=True)
#   File "/home/neha/Envs/sajiloyatra/lib/python3.6/site-packages/pandas/core/indexing.py", line 1354, in _convert_to_indexer
#     return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#   File "/home/neha/Envs/sajiloyatra/lib/python3.6/site-packages/pandas/core/indexing.py", line 1161, in _get_listlike_indexer
#     raise_missing=raise_missing)
#   File "/home/neha/Envs/sajiloyatra/lib/python3.6/site-packages/pandas/core/indexing.py", line 1246, in _validate_read_indexer
#     key=key, axis=self.obj._get_axis_name(axis)))
# KeyError: "None of [Int64Index([ 45,  44,  27,  90,  17,  41,  21,  32,  94,  40, 105,  91,  25,\n              1,  26,  12,  79,   9,  62,  86,  48,  98, 121,  20, 117,  89,\n            106, 113,  13,  75,  71,   0],\n           dtype='int64')] are in the [columns]"
